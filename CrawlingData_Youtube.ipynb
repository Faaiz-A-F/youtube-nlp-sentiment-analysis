# %% [markdown]
# # **Crawling Data Youtube**

# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
API_KEY = '' #add your api key here
YOUTUBE_API_SERVICE_NAME = 'youtube'
YOUTUBE_API_VERSION = 'v3'

# %%
def get_comment(video_id):
    youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)
    comments = []
    responses = youtube.commentThreads().list(
        part ='snippet',
        videoId = video_id,
        textFormat = 'plainText'
    ).execute()

    while responses:
        for item in responses['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comments.append(comment)
        if 'nextPageToken' in responses:
            responses = youtube.commentThreads().list(
                part = 'snippet',
                videoId = video_id,
                pageToken = responses['nextPageToken'],
                textFormat = 'plainText'
            ).execute()
        else:
            break
    return comments

# %%
import os
os.makedirs('./data', exist_ok=True)

# %%
video_id = 'shoYSQlKgKY'
comments = get_comment(video_id)
df = pd.DataFrame(comments, columns=['comments'])
df.to_csv('./data/comments1.csv', index=False)

video_id = 'rwnAUvUtuVw'
comments = get_comment(video_id)
df = pd.DataFrame(comments, columns=['comments'])
df.to_csv('./data/comments2.csv', index=False)

video_id = 'wbK0V2ASJf8'
comments = get_comment(video_id)
df = pd.DataFrame(comments, columns=['comments'])
df.to_csv('./data/comments3.csv', index=False)

video_id = 'vkuBFTAPuU8'
comments = get_comment(video_id)
df = pd.DataFrame(comments, columns=['comments'])
df.to_csv('./data/comments4.csv', index=False)

video_id = 'aL9lwfA04B8'
comments = get_comment(video_id)
df = pd.DataFrame(comments, columns=['comments'])
df.to_csv('./data/comments5.csv', index=False)

video_id = 'THS32PEr9JQ'
comments = get_comment(video_id)
df = pd.DataFrame(comments, columns=['comments'])
df.to_csv('./data/comments6.csv', index=False)

# %%
df1 = pd.read_csv('./data/comments1.csv')
df2 = pd.read_csv('./data/comments2.csv')
df3 = pd.read_csv('./data/comments3.csv')
df4 = pd.read_csv('./data/comments4.csv')
df5 = pd.read_csv('./data/comments5.csv')
df6 = pd.read_csv('./data/comments6.csv')

result = pd.concat([df1, df2, df3, df4, df5, df6], axis=0, join='inner').drop_duplicates(subset='comments')

result.to_csv('./data/dataset_comment_yt.csv', index=False)

print(result)
# Out:
#                                                comments
# 0     Makin lama makin ke sini hukum semakin ga jela...
# 1           Gila bnr padahal di pilih dari suara rakyat
# 2     HOUWWWWW...AKAN. ANYAK RAKYAT YANG DI PENJARA....
# 3       Seru bisa rakyat semua  turun kejal ini  mantap
# 4     Kaya anak teka undang2..begituh ga berbobot bp...
# ...                                                 ...
# 3865  Wah bahaya itu kodenya berarti mereka mau akal...
# 3866                                     Emg itu bahlul
# 3867  Bukan kali ini bahlul itu colek colek,sudah mu...
# 3868      Awas pak waspada ada yg sudah ngasi kode pak.
# 3869  Ada apa gerangan tangan nya Bahlil colek" bos ...
#
# [24357 rows x 1 columns]
